# %%
import pandas as pd
import matplotlib.pyplot as plt
Excel_file = "C:\RentPath\RentPath-TicketDetails.xlsx"
Ticket = pd.read_excel(Excel_file)
Ticket = pd.DataFrame(data, columns= ['Case Number'])
print(Ticket)
# Out:
#     Case Number
# 0       1743891
# 1     01744456
# 2     01744468
# 3     01744594
# 4     01745460
# 5     01746549
# 6     01747033
# 7     01747657
# 8      01747661
# 9      01748234
# 10    01748286
# 11     01748866
# 12    01749579
# 13    01750192
# 14    01750207
# 15     01750227
# 16    01750576
# 17    01750898
# 18    01751106
# 19     01751499
# 20     01752158
# 21     01752237
# 22    01753254
# 23     01754309
# 24     01754869
# 25     01756820
# 26     01757269
# 27     01757270
# 28     01759044
# 29     01759045
# ..          ...
# 560    01928923
# 561   01929566
# 562   01929572
# 563   01929572
# 564   01929624
# 565   01929632
# 566   01929745
# 567    01930632
# 568    01931503
# 569   01932241
# 570    01932250
# 571    01932307
# 572         NaN
# 573   01925190
# 574   01933179
# 575   01925190
# 576   01933874
# 577   01933944
# 578   01933950
# 579         NaN
# 580         NaN
# 581    01934121
# 582    01934121
# 583  01935048
# 584   01935144
# ...

# %%
import pandas as pd

data = pd.read_excel (r"C:\RentPath\RentPath-TicketDetails.xlsx") 
XC = pd.DataFrame(data, columns =  ['Case Number'])
print (XC)
# Out:
#     Case Number
# 0       1743891
# 1     01744456
# 2     01744468
# 3     01744594
# 4     01745460
# 5     01746549
# 6     01747033
# 7     01747657
# 8      01747661
# 9      01748234
# 10    01748286
# 11     01748866
# 12    01749579
# 13    01750192
# 14    01750207
# 15     01750227
# 16    01750576
# 17    01750898
# 18    01751106
# 19     01751499
# 20     01752158
# 21     01752237
# 22    01753254
# 23     01754309
# 24     01754869
# 25     01756820
# 26     01757269
# 27     01757270
# 28     01759044
# 29     01759045
# ..          ...
# 560    01928923
# 561   01929566
# 562   01929572
# 563   01929572
# 564   01929624
# 565   01929632
# 566   01929745
# 567    01930632
# 568    01931503
# 569   01932241
# 570    01932250
# 571    01932307
# 572         NaN
# 573   01925190
# 574   01933179
# 575   01925190
# 576   01933874
# 577   01933944
# 578   01933950
# 579         NaN
# 580         NaN
# 581    01934121
# 582    01934121
# 583  01935048
# 584   01935144
# ...

# %%
import tkinter as tk
from tkinter import filedialog
import pandas as pd

root= tk.Tk()

canvas1 = tk.Canvas(root, width = 300, height = 300, bg = 'lightsteelblue')
canvas1.pack()

def getExcel ():
    global df
    
    import_file_path = filedialog.askopenfilename()
    df = pd.read_excel (import_file_path)
    print (df)
    
browseButton_Excel = tk.Button(text='Import Excel File', command=getExcel, bg='green', fg='white', font=('helvetica', 12, 'bold'))
canvas1.create_window(150, 150, window=browseButton_Excel)

root.mainloop()
# Out:
#      Sl No #       Date  Resource Name   \
# 0        1.0 2019-01-28      Om Prakash
# 1        NaN        NaT             NaN
# 2        NaN        NaT             NaN
# 3        NaN        NaT             NaN
# 4        NaN        NaT             NaN
# 5        NaN        NaT             NaN
# 6        NaN        NaT             NaN
# 7        NaN        NaT             NaN
# 8        2.0 2019-03-08  Balaji Battina
# 9        NaN        NaT             NaN
# 10       NaN        NaT             NaN
# 11       3.0 2019-03-11  Balaji Battina
# 12       NaN        NaT             NaN
# 13       NaN        NaT             NaN
# 14       4.0 2019-03-12  Balaji Battina
# 15       NaN        NaT             NaN
# 16       5.0 2019-03-13  Balaji Battina
# 17       NaN        NaT             NaN
# 18       NaN        NaT             NaN
# 19       6.0 2019-03-14  Balaji Battina
# 20       NaN        NaT             NaN
# 21       7.0 2019-03-15  Balaji Battina
# ...
